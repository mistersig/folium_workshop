# %%
import os
import numpy
import folium
import geopandas
print('success')
# Out:
# success

# %%
m = folium.Map(location=[48,-120])

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save('index.html')

# %%
folium.Map(
    location=[45.5236, -122.6750],
    tiles='CartoDB positron',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CTA = os.path.join('data/CTA_RailLines/', 'CTA_RailLines.shp')
rail = geopandas.read_file(CTA)
rail
# Out:
#      OBJECTID  ASSET_ID                    LINES  \
# 0           1  21100001  Blue Line (Forest Park)
# 1          10  21100010  Blue Line (Forest Park)
# 2          19  21100019       Blue Line (O'Hare)
# 3          24  21100024  Blue Line (Forest Park)
# 4          46  21100046       Blue Line (O'Hare)
# 5          48  21100048       Blue Line (O'Hare)
# 6          53  21100053                 Red Line
# 7          54  21100054                 Red Line
# 8          56  21100056                 Red Line
# 9          57  21100057                 Red Line
# 10         59  21100060  Blue Line (Forest Park)
# 11         60  21100061  Blue Line (Forest Park)
# 12         61  21100062       Blue Line (O'Hare)
# 13         62  21100063  Blue Line (Forest Park)
# 14         63  21100064  Blue Line (Forest Park)
# 15         76  21100078       Blue Line (O'Hare)
# 16         88  21100093       Blue Line (O'Hare)
# 17         89  21100094                 Red Line
# ...

# %%
m = folium.Map([41.884510, -87.630232], zoom_start=10, tiles='cartodbpositron')

folium.GeoJson(rail).add_to(m)
m.save('index.html')
# m.save(os.path.join('results', 'geopandas_0.html'))

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
rail['style'] = [
    {'fillColor': '#c60c30', 'weight': 1, 'color': 'black'},
    {'fillColor': '#00a1de', 'weight': 1, 'color': 'black'},
    {'fillColor': '#62361b', 'weight': 1, 'color': 'black'},
    {'fillColor': '#009b3a', 'weight': 1, 'color': 'black'},
    {'fillColor': '#f9461c', 'weight': 1, 'color': 'black'},
    {'fillColor': '#522398', 'weight': 1, 'color': 'black'},
    {'fillColor': '#e27ea6', 'weight': 1, 'color': 'black'},
    {'fillColor': '#f9e300', 'weight': 1, 'color': 'black'},
]
rail
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-7dc9642d92dd> in <module>
#       4     {'fillColor': '#62361b', 'weight': 1, 'color': 'black'},
#       5     {'fillColor': '#009b3a', 'weight': 1, 'color': 'black'},
# ----> 6     {'fillColor': '#f9461c', 'weight': 1, 'color': 'black'},
#       7 ]
#       8 rail
#
# ~/anaconda3/envs/folium/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/anaconda3/envs/folium/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3443
#    3444         self._ensure_valid_index(value)
# -> 3445         value = self._sanitize_column(key, value)
# ...
